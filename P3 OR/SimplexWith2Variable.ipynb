# %% [markdown]
# Roll No. - 15, Name - Kajal Mishra

# %% [markdown]
# LPP with two variable using Simplex method

# %%
from scipy.optimize import linprog

# %%
obj = [-3, -2]

# %%
lhs_ineq = [[1, 1],
            [1, -1],]

# %%
rhs_ineq = [4,
            2]

# %%
bnd = [(0, float("inf")),
       (0, float("inf"))]

# %%
opt = linprog(c=obj, A_ub=lhs_ineq, b_ub=rhs_ineq, bounds=bnd, method="revised simplex")

# %%
opt
# Out:
#      con: array([], dtype=float64)
#      fun: -11.0
#  message: 'Optimization terminated successfully.'
#      nit: 2
#    slack: array([0., 0.])
#   status: 0
#  success: True
#        x: array([3., 1.])
